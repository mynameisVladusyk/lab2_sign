# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Зчитуємо сигнал
stab1 = pd.read_csv('Downloads\\laba\\1.csv', header = None, sep = ' ')
x1 = stab1[5]
y1 = stab1[6]
#Побудова графіка
fig, ax = plt.subplots(figsize=(15,15))
ax.set_xlabel('Вісь X, см')
ax.set_ylabel('Вісь Y, см')
ax.set_title('Графік стабілограми (координати)')
ax.plot(x1,y1)
plt.show()
