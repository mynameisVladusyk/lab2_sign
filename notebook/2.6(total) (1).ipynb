# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Зчитуємо сигнал 
stab1 = pd.read_csv('Downloads\\laba\\1.csv', header = None, sep = ' ')
x1 = stab1[0]
y1 = stab1[7]
#Побудова графіка
fig, ax = plt.subplots(figsize=(12,7))
ax.set_xlabel('time, ms')
ax.set_ylabel('total f')
ax.set_title('Acrob base open total')
ax.plot(x1,y1)
plt.show()
