# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#base_open
stab1 = pd.read_csv('Downloads\\laba\\1.csv', header = None, sep = ' ')
x1 = stab1[0]
y1 = stab1[5]
y1_1 = stab1[6]
#sway_front-back
stab2 = pd.read_csv('Downloads\\laba\\2.csv', header = None, sep = ' ')
x2 = stab2[0]
y2 = stab2[5]
y2_1 = stab2[6]
#sway_left-right
stab3 = pd.read_csv('Downloads\\laba\\5.csv', header = None, sep = ' ')
x3 = stab3[0]
y3 = stab3[5]
y3_1 = stab3[6]
#Побудова графіків
fig, axes=plt.subplots(nrows=3,ncols=2,figsize = (10,7))
baseX,baseY, frontX,frontY,leftX,leftY = axes.flatten()
baseX.plot(x1,y1,lw=1)
baseX.set_xlabel('time(s)',fontsize=10)
baseX.set_ylabel('cm',fontsize=10)
baseX.set_title('base_openX',fontsize=10)

frontX.plot(x2,y2,lw=1)
frontX.set_xlabel('time(s)',fontsize=10)
frontX.set_ylabel('cm',fontsize=10)
frontX.set_title('sway_front-back_60X',fontsize=10)

leftX.plot(x3,y3,lw=1)
leftX.set_xlabel('time(s)',fontsize=10)
leftX.set_ylabel('cm',fontsize=10)
leftX.set_title('sway_left-right_60X',fontsize=10)

baseY.plot(x1,y1_1,lw=1)
baseY.set_xlabel('time(s)',fontsize=10)
baseY.set_ylabel('cm',fontsize=10)
baseY.set_title('base_openY',fontsize=10)

frontY.plot(x2,y2_1,lw=1)
frontY.set_xlabel('time(s)',fontsize=10)
frontY.set_ylabel('cm',fontsize=10)
frontY.set_title('sway_front-back_60Y',fontsize=10)

leftY.plot(x3,y3_1,lw=1)
leftY.set_xlabel('time(s)',fontsize=10)
leftY.set_ylabel('cm',fontsize=10)
leftY.set_title('sway_left-right_60Y',fontsize=10)
fig.tight_layout()

# %%
def duration(Signal, Fs):
    Ts = 1/Fs
    sig_duration = len(Signal)/Fs
    t = np.arange(0, sig_duration, Ts)
    return sig_duration, t
duration(stab1,256)
# Out:
# (10.3984375,
#  array([0.00000000e+00, 3.90625000e-03, 7.81250000e-03, ...,
#         1.03867188e+01, 1.03906250e+01, 1.03945312e+01]))

# %%
duration(stab2, 256)
# Out:
# (10.44140625,
#  array([0.00000000e+00, 3.90625000e-03, 7.81250000e-03, ...,
#         1.04296875e+01, 1.04335938e+01, 1.04375000e+01]))

# %%
duration(stab3, 256)
# Out:
# (10.6796875,
#  array([0.00000000e+00, 3.90625000e-03, 7.81250000e-03, ...,
#         1.06679688e+01, 1.06718750e+01, 1.06757812e+01]))
